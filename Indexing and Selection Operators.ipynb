# %%
import pandas as pd
data = pd.read_csv("nba-2.csv",index_col="Team")
second = data["Salary"]
second = data.loc["Boston Celtics"]
second
# Out:
#                            Name  Number Position  Age  Height  Weight  \
# Team
# Boston Celtics    Avery Bradley       0       PG   25   2-Jun     180
# Boston Celtics      Jae Crowder      99       SF   25   6-Jun     235
# Boston Celtics     John Holland      30       SG   27   5-Jun     205
# Boston Celtics      R.J. Hunter      28       SG   22   5-Jun     185
# Boston Celtics    Jonas Jerebko       8       PF   29  10-Jun     231
# Boston Celtics     Amir Johnson      90       PF   29   9-Jun     240
# Boston Celtics    Jordan Mickey      55       PF   21   8-Jun     235
# Boston Celtics     Kelly Olynyk      41        C   25  Jul-00     238
# Boston Celtics     Terry Rozier      12       PG   22   2-Jun     190
# Boston Celtics     Marcus Smart      36       PG   22   4-Jun     220
# Boston Celtics  Jared Sullinger       7        C   24   9-Jun     260
# Boston Celtics    Isaiah Thomas       4       PG   27   9-May     185
# ...

# %%
first = data[["Number","Name","Height","Weight"]]
first
# Out:
#                 Number           Name  Height  Weight
# Team
# Boston Celtics       0  Avery Bradley   2-Jun     180
# Boston Celtics      99    Jae Crowder   6-Jun     235
# Boston Celtics      30   John Holland   5-Jun     205
# Boston Celtics      28    R.J. Hunter   5-Jun     185
# Boston Celtics       8  Jonas Jerebko  10-Jun     231
# ...                ...            ...     ...     ...
# Utah Jazz           41     Trey Lyles  10-Jun     234
# Utah Jazz            8   Shelvin Mack   3-Jun     203
# Utah Jazz           25      Raul Neto   1-Jun     179
# Utah Jazz           21   Tibor Pleiss   3-Jul     256
# Utah Jazz           24    Jeff Withey  Jul-00     231
#
# [457 rows x 4 columns]

# %%
import pandas as pd
data = pd.read_csv("nba-2.csv",index_col="Name")
first = data.loc["Avery Bradley"]
second = data.loc["R.J. Hunter"]
print(first, "\n\n\n" ,second)
# Out:
# Team        Boston Celtics
# Number                   0
# Position                PG
# Age                     25
# Height               2-Jun
# Weight                 180
# College              Texas
# Salary           7730337.0
# Name: Avery Bradley, dtype: object
#
#
#  Team        Boston Celtics
# Number                  28
# Position                SG
# Age                     22
# Height               5-Jun
# Weight                 185
# College      Georgia State
# Salary           1148640.0
# Name: R.J. Hunter, dtype: object

# %%
first = data.loc[["Avery Bradley" , "R.J. Hunter"]]
first
# Out:
#                          Team  Number Position  Age Height  Weight  \
# Name
# Avery Bradley  Boston Celtics       0       PG   25  2-Jun     180
# R.J. Hunter    Boston Celtics      28       SG   22  5-Jun     185
#
#                      College     Salary
# Name
# Avery Bradley          Texas  7730337.0
# R.J. Hunter    Georgia State  1148640.0

# %%
first = data.loc[["Avery Bradley" , "R.J. Hunter","Tyler Zeller"],
                ["Team","Number","Salary"]]
first
# Out:
#                          Team  Number     Salary
# Name
# Avery Bradley  Boston Celtics       0  7730337.0
# R.J. Hunter    Boston Celtics      28  1148640.0
# Tyler Zeller   Boston Celtics      44  2616975.0

# %%
first = data.loc[:, ["Team" , "Salary" , "Position"]]
first
# Out:
#                          Team     Salary Position
# Name
# Avery Bradley  Boston Celtics  7730337.0       PG
# Jae Crowder    Boston Celtics  6796117.0       SF
# John Holland   Boston Celtics        NaN       SG
# R.J. Hunter    Boston Celtics  1148640.0       SG
# Jonas Jerebko  Boston Celtics  5000000.0       PF
# ...                       ...        ...      ...
# Trey Lyles          Utah Jazz  2239800.0       PF
# Shelvin Mack        Utah Jazz  2433333.0       PG
# Raul Neto           Utah Jazz   900000.0       PG
# Tibor Pleiss        Utah Jazz  2900000.0        C
# Jeff Withey         Utah Jazz   947276.0        C
#
# [457 rows x 3 columns]

# %%
row2 = data.iloc[49]
row2
# Out:
# Team        Philadelphia 76ers
# Number                      21
# Position                     C
# Age                         22
# Height                  Jul-00
# Weight                     250
# College                 Kansas
# Salary               4626960.0
# Name: Joel Embiid, dtype: object

# %%
row = data.iloc[[2,58,96]]
row
# Out:
#                                Team  Number Position  Age  Height  Weight  \
# Name
# John Holland         Boston Celtics      30       SG   27   5-Jun     205
# Nik Stauskas     Philadelphia 76ers      11       SG   22   6-Jun     205
# Blake Griffin  Los Angeles Clippers      32       PF   27  10-Jun     251
#
#                          College      Salary
# Name
# John Holland   Boston University         NaN
# Nik Stauskas            Michigan   2869440.0
# Blake Griffin           Oklahoma  18907726.0

# %%
row3 = data.iloc[[3,5],[1,2]]
row3
# Out:
#               Number Position
# Name
# R.J. Hunter       28       SG
# Amir Johnson      90       PF
